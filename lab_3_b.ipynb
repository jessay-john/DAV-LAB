# %%
import pandas as pd
import numpy as np

# Create mock data for UCI Diabetes
uci_mock = pd.DataFrame({
    'Glucose': np.random.randint(70, 200, 100),
    'BloodPressure': np.random.randint(60, 120, 100),
    'BMI': np.random.uniform(18, 45, 100),
    'Age': np.random.randint(20, 80, 100),
    'Outcome': np.random.randint(0, 2, 100)
})
uci_mock.to_csv('uci_diabetes (3).csv', index=False)

# Create mock data for Pima Diabetes
pima_mock = pd.DataFrame({
    'Glucose': np.random.randint(70, 200, 100),
    'BloodPressure': np.random.randint(60, 120, 100),
    'BMI': np.random.uniform(18, 45, 100),
    'Age': np.random.randint(20, 80, 100),
    'Outcome': np.random.randint(0, 2, 100)
})
pima_mock.to_csv('pima_diabetes (3).csv', index=False)

print('Mock CSV files created successfully!')
# Out:
# Mock CSV files created successfully!

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import r2_score, accuracy_score

# Load the Datasets
uci_diabetes = pd.read_csv("uci_diabetes (3).csv")
pima_diabetes = pd.read_csv("pima_diabetes (3).csv")

# Display first few rows
print("UCI Diabetes Dataset Sample:\n", uci_diabetes.head())
print("\nPima Indians Diabetes Dataset Sample:\n", pima_diabetes.head())

# Perform Linear Regression (Glucose vs. BMI)
def linear_regression_analysis(df, x_column, y_column):
    X = df[[x_column]] # Independent variable
    Y = df[y_column] # Dependent variable
    model = LinearRegression()
    model.fit(X, Y)
    Y_pred = model.predict(X)
    r2 = r2_score(Y, Y_pred)
    print(f"\nLinear Regression (Predicting {y_column} using {x_column}):")
    print(f"R² Score: {r2:.4f}")
    # Plot
    plt.figure(figsize=(8, 4))
    plt.scatter(X, Y, color='blue', label='Actual Data')
    plt.plot(X, Y_pred, color='red', linewidth=2, label='Regression Line')
    plt.xlabel(x_column)
    plt.ylabel(y_column)
    plt.title(f"Linear Regression: {x_column} vs. {y_column}")
    plt.legend()
    plt.show()

# Apply Linear Regression on both datasets
linear_regression_analysis(uci_diabetes, "Glucose", "BMI")
linear_regression_analysis(pima_diabetes, "Glucose", "BMI")

# Perform Logistic Regression (Predicting Diabetes)
def logistic_regression_analysis(df, features, target):
    X = df[features]
    Y = df[target]
    # Splitting dataset
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
    model = LogisticRegression()
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    accuracy = accuracy_score(Y_test, Y_pred)
    print(f"\nLogistic Regression (Predicting {target} using {features}):")
    print(f"Accuracy Score: {accuracy:.4f}")

# Select features and target
features = ["Glucose", "BloodPressure", "BMI", "Age"]
target = "Outcome"

# Apply Logistic Regression on both datasets
logistic_regression_analysis(uci_diabetes, features, target)
logistic_regression_analysis(pima_diabetes, features, target)
# Out:
# UCI Diabetes Dataset Sample:
#     Glucose  BloodPressure        BMI  Age  Outcome
# 0      140             84  34.630984   33        1
# 1      168             89  44.188131   46        1
# 2      175             67  39.782155   42        0
# 3      100            100  19.619265   33        1
# 4      101             88  18.884099   30        1
#
# Pima Indians Diabetes Dataset Sample:
#     Glucose  BloodPressure        BMI  Age  Outcome
# 0      138             81  31.724462   26        0
# 1      170            107  44.827125   21        1
# 2      103            109  38.118804   53        0
# 3      159             94  27.844054   51        0
# 4       73             87  35.962037   36        1
#
# Linear Regression (Predicting BMI using Glucose):
# R² Score: 0.0175
# Linear Regression (Predicting BMI using Glucose):
# R² Score: 0.0031
# Logistic Regression (Predicting Outcome using ['Glucose', 'BloodPressure', 'BMI', 'Age']):
# Accuracy Score: 0.5000
#
# Logistic Regression (Predicting Outcome using ['Glucose', 'BloodPressure', 'BMI', 'Age']):
# Accuracy Score: 0.5000

# %% [markdown]
# ### Dataset Viewer
# Below are the interactive tables for the mock datasets created.

# %%
from google.colab import data_table

print("UCI Diabetes Mock Dataset:")
display(data_table.DataTable(uci_diabetes, include_index=False, num_rows_per_page=10))

print("\nPima Indians Diabetes Mock Dataset:")
display(data_table.DataTable(pima_diabetes, include_index=False, num_rows_per_page=10))
# Out:
# UCI Diabetes Mock Dataset:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Glucose</th>
#       <th>BloodPressure</th>
#       <th>BMI</th>
#       <th>Age</th>
#       <th>Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>140</td>
#       <td>84</td>
#       <td>34.630984</td>
#       <td>33</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>168</td>
#       <td>89</td>
#       <td>44.188131</td>
#       <td>46</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>175</td>
#       <td>67</td>
#       <td>39.782155</td>
#       <td>42</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>100</td>
#       <td>100</td>
#       <td>19.619265</td>
#       <td>33</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>101</td>
#       <td>88</td>
#       <td>18.884099</td>
#       <td>30</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>91</td>
#       <td>82</td>
#       <td>22.794857</td>
#       <td>46</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>177</td>
#       <td>102</td>
#       <td>19.685727</td>
#       <td>32</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>110</td>
#       <td>81</td>
#       <td>36.815500</td>
#       <td>39</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>175</td>
#       <td>79</td>
#       <td>36.570712</td>
#       <td>67</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>142</td>
#       <td>106</td>
#       <td>24.957217</td>
#       <td>46</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 5 columns</p>
# </div>
# Pima Indians Diabetes Mock Dataset:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Glucose</th>
#       <th>BloodPressure</th>
#       <th>BMI</th>
#       <th>Age</th>
#       <th>Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>138</td>
#       <td>81</td>
#       <td>31.724462</td>
#       <td>26</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>170</td>
#       <td>107</td>
#       <td>44.827125</td>
#       <td>21</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>103</td>
#       <td>109</td>
#       <td>38.118804</td>
#       <td>53</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>159</td>
#       <td>94</td>
#       <td>27.844054</td>
#       <td>51</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>73</td>
#       <td>87</td>
#       <td>35.962037</td>
#       <td>36</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>180</td>
#       <td>66</td>
#       <td>22.311338</td>
#       <td>77</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>120</td>
#       <td>116</td>
#       <td>31.236668</td>
#       <td>61</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>108</td>
#       <td>98</td>
#       <td>28.645769</td>
#       <td>46</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>126</td>
#       <td>107</td>
#       <td>38.249902</td>
#       <td>24</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>115</td>
#       <td>64</td>
#       <td>33.087088</td>
#       <td>31</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 5 columns</p>
# </div>

# %% [markdown]
# ### Download CSV Files
# Run the cell below to download the mock datasets to your local machine.

# %%
from google.colab import files

# Download the UCI dataset
files.download('uci_diabetes (3).csv')

# Download the Pima dataset
files.download('pima_diabetes (3).csv')
